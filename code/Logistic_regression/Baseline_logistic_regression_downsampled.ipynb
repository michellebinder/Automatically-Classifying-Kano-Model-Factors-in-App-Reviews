# %%
# Imports
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import KFold
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, matthews_corrcoef
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Data processing

# %%
def getDataAndLabel(df, dataColumnName, labelColumnName):

  X = df.loc[:, dataColumnName].to_numpy()
  y = df.loc[:, labelColumnName].to_numpy()

  n = np.size(X)

  X_train = ['']*n
  y_train = ['']*n

  for i in range(n):
    X_train[i] += str(X[i])
    y_train[i] += str(y[i])

  return X_train, y_train

# %%
def getDataClass(df, dataColumnName, labelColumnName):
  X = df.loc[:, dataColumnName].to_numpy()
  y = df.loc[:, labelColumnName].to_numpy()

  train_classes = ['']*4

  n = np.size(X)

  for i in range(n):
    if (y[i] == 'B'):
      train_classes[0] += str(X[i]) + '. '
    
    if (y[i] == 'D'):
      train_classes[1] += str(X[i]) + '. '
    
    if (y[i] == 'I'):
      train_classes[2] += str(X[i]) + '. '
    
    if (y[i] == 'P'):
      train_classes[3] += str(X[i]) + '. '
    
  return train_classes

# %% [markdown]
# ##Label functions

# %%
def predict(X_train, y_train, X_test, y_test, tfidf):

  X_train_transformed = tfidf.fit_transform(X_train)
  X_test_transformed = tfidf.transform(X_test)

  lr = LogisticRegression(max_iter = 1000)
  lr.fit(X_train_transformed, y_train)
  y_pred = lr.predict(X_test_transformed)

  return y_pred

# %% [markdown]
# ##Evaluation on Testset

# %%
def evalOnDataset(df_train, df_test):
  X_train, y_train = getDataAndLabel(df_train, 'review', 'kano_labels')
  tfidf = TfidfVectorizer(input = getDataClass(df_train, 'review', 'kano_labels'), stop_words = "english")

  X_test, y_test = getDataAndLabel(df_test, 'review', 'kano_labels')

  y_pred = predict(X_train, y_train, X_test, y_test, tfidf)

  acc = accuracy_score(y_test, y_pred)
  prec, rec, f1, supp = precision_recall_fscore_support(y_test, y_pred, average = 'macro')

  print("accuracy:\t", acc)
  print("precision:\t", prec)
  print("recall:\t", rec)
  print("f1 score:\t", f1)

  df_test['prediction'] = y_pred
  df_test.to_excel("Brunotte_with_predictions_test" + str(i) + "_logistic_regression.xlsx")

# %% [markdown]
# ##Evaluation on Testset divided by labels

# %%
def evalOnDatasetByLabel(df_train, df_test):
  X_train, y_train = getDataAndLabel(df_train, 'review', 'kano_labels')
  tfidf = TfidfVectorizer(input = getDataClass(df_train, 'review', 'kano_labels'), stop_words = "english")

  accuracy = []
  precision = []
  recall = []
  f1_score = []

  for label in ["B", "P", "D", "I"]:
    X_test, y_test = getDataAndLabel(df_test[df_test.kano_labels == label], 'review', 'kano_labels')
    print("------------------------------")
    print("evaluating label", label)
    print("------------------------------")

    y_pred = predict(X_train, y_train, X_test, y_test, tfidf)
    acc = accuracy_score(y_test, y_pred)
    prec, rec, f1, sup = precision_recall_fscore_support(y_test, y_pred, average='macro', zero_division = 1)

    print("accuracy:\t", acc)
    print("precision:\t", prec)
    print("recall:\t", rec)
    print("f1 score:\t", f1)

    accuracy.append(acc)
    precision.append(prec)
    recall.append(rec)
    f1_score.append(f1)

# %% [markdown]
# ##10-fold cross-validation

# %%
def crossvalidation10fold(train_data):
  # 10 fold cross validation
  n = 10
  kf = KFold(n_splits=n, random_state = 42, shuffle = True)

  tfidf = TfidfVectorizer(input = getDataClass(train_data, 'review', 'kano_labels'), stop_words = "english")

  # Lists to store the values for accuracy, precision, recall and f1-score for each label
  resultsAcc = [[],[],[],[],[]]
  resultsPrecision = [[],[],[],[],[]]
  resultsRecall = [[],[],[],[],[]]
  resultsf1 = [[],[],[],[],[]]

  for train_index, val_index in kf.split(train_data):
    train_df = train_data.iloc[train_index]
    val_df = train_data.iloc[val_index]

    X_train, y_train = getDataAndLabel(train_df, 'review', 'kano_labels')

    # Evaluating on the val_df divided by labels
    for i, label in zip(range(4), ["B", "P", "D", "I"]):
      X_test, y_test = getDataAndLabel(val_df[val_df.kano_labels == label], 'review', 'kano_labels')

      y_pred = predict(X_train, y_train, X_test, y_test, tfidf)

      acc = accuracy_score(y_test, y_pred)
      prec, rec, f1, sup = precision_recall_fscore_support(y_test, y_pred, average='macro', zero_division = 1)

      resultsAcc[i].append(acc)
      resultsPrecision[i].append(prec)
      resultsRecall[i].append(rec)
      resultsf1[i].append(f1)

    # Evaluating on the whole val_df
    X_test, y_test = getDataAndLabel(val_df, 'review', 'kano_labels')

    y_pred = predict(X_train, y_train, X_test, y_test, tfidf)

    acc = accuracy_score(y_test, y_pred)
    prec, rec, f1, sup = precision_recall_fscore_support(y_test, y_pred, average='macro', zero_division = 1)

    resultsAcc[4].append(acc)
    resultsPrecision[4].append(prec)
    resultsRecall[4].append(rec)
    resultsf1[4].append(f1)
  
  for i, label in zip(range(5), ["basic", "performance", "delighter", "irrelevant", "overall"]):
    print("------------\n", label, "\n------------")
    print("Average accuracy:\t", np.round(np.average(resultsAcc[i]), 3))
    print("Average precision:\t", np.round(np.average(resultsPrecision[i]), 3))
    print("Average recall:\t", np.round(np.average(resultsRecall[i]), 3))
    print("Average f1 score:\t", np.round(np.average(resultsf1[i]), 3))

# %% [markdown]
# # Import Data

# %%
for i in range(1,6):
  # Import of the datasets
  training_dataset = pd.read_excel('DATASET_downsampled_test' + str(i) + '.xlsx')
  test_dataset = pd.read_excel('Trainingskorpus_Final.xlsx')
  combined_dataset = pd.read_excel('DATASET_Trainingskorpus_combined_test' + str(i) + '.xlsx')
  
  print("======================================\
  ITERATION " + str(i) + "\
  ======================================\n")

  #Run training on training set, evaluation on test set
  print("--------------------------\
  TRAINING ON TRAINING SET, EVALUATION ON TEST SET\
  -------------------------")
  evalOnDataset(training_dataset, test_dataset)
  print("\n\n")

  #Run training on training set, evaluation on test set --- devided by labels
  print("--------------------------\
  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL\
  -------------------------")
  evalOnDatasetByLabel(training_dataset, test_dataset)
  print("\n\n")

  #Perform a 10-fold cross-validation on the Murat Dataset
  print("--------------------------\
  CROSS-VALIDATION ON TRAINING SET\
  -------------------------")
  crossvalidation10fold(training_dataset)
  print("\n\n")

  #Perform a 10-fold cross-validation on the combined Dataset
  print("--------------------------\
  CROSS-VALIDATION ON COMBINED SET\
  -------------------------")
  crossvalidation10fold(combined_dataset)
  print("\n\n\n\n")
  print("\n\n\n\n")
# Out:
# ======================================  ITERATION 1  ======================================
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET  -------------------------
# accuracy:	 0.5869297163995068
# precision:	 0.3841541312517382
# recall:	 0.45953502262859247
# f1 score:	 0.38085538580931827
#
#
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL  -------------------------
# ------------------------------
# evaluating label B
# ------------------------------
# accuracy:	 0.661524500907441
# precision:	 0.25
# recall:	 0.9153811252268602
# f1 score:	 0.19907154560349535
# ------------------------------
# evaluating label P
# ------------------------------
# accuracy:	 0.3924050632911392
# precision:	 0.25
# recall:	 0.8481012658227848
# f1 score:	 0.14090909090909093
# ------------------------------
# evaluating label D
# ------------------------------
# accuracy:	 0.6842105263157895
# precision:	 0.25
# recall:	 0.9210526315789473
# f1 score:	 0.20312500000000003
# ------------------------------
# evaluating label I
# ------------------------------
# accuracy:	 0.1
# precision:	 0.25
# recall:	 0.775
# f1 score:	 0.045454545454545456
#
#
#
# --------------------------  CROSS-VALIDATION ON TRAINING SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.832
# Average precision:	 0.258
# Average recall:	 0.957
# Average f1 score:	 0.235
# ------------
#  performance
# ------------
# Average accuracy:	 0.532
# Average precision:	 0.25
# Average recall:	 0.883
# Average f1 score:	 0.173
# ------------
#  delighter
# ------------
# Average accuracy:	 0.555
# Average precision:	 0.267
# Average recall:	 0.882
# Average f1 score:	 0.19
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.743
# Average precision:	 0.25
# Average recall:	 0.936
# Average f1 score:	 0.213
# ------------
#  overall
# ------------
# Average accuracy:	 0.665
# Average precision:	 0.661
# Average recall:	 0.666
# Average f1 score:	 0.661
#
#
#
# --------------------------  CROSS-VALIDATION ON COMBINED SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.834
# Average precision:	 0.267
# Average recall:	 0.956
# Average f1 score:	 0.242
# ------------
#  performance
# ------------
# Average accuracy:	 0.495
# Average precision:	 0.25
# Average recall:	 0.874
# Average f1 score:	 0.165
# ------------
#  delighter
# ------------
# Average accuracy:	 0.552
# Average precision:	 0.25
# Average recall:	 0.888
# Average f1 score:	 0.177
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.735
# Average precision:	 0.25
# Average recall:	 0.934
# Average f1 score:	 0.212
# ------------
#  overall
# ------------
# Average accuracy:	 0.654
# Average precision:	 0.647
# Average recall:	 0.654
# Average f1 score:	 0.647
#
#
#
#
#
#
#
#
#
#
# ======================================  ITERATION 2  ======================================
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET  -------------------------
# accuracy:	 0.62577065351418
# precision:	 0.40095299940059925
# recall:	 0.4766209500179957
# f1 score:	 0.3995028611850374
#
#
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL  -------------------------
# ------------------------------
# evaluating label B
# ------------------------------
# accuracy:	 0.7041742286751361
# precision:	 0.25
# recall:	 0.9260435571687841
# f1 score:	 0.20660276890308837
# ------------------------------
# evaluating label P
# ------------------------------
# accuracy:	 0.43037974683544306
# precision:	 0.25
# recall:	 0.8575949367088608
# f1 score:	 0.1504424778761062
# ------------------------------
# evaluating label D
# ------------------------------
# accuracy:	 0.7052631578947368
# precision:	 0.25
# recall:	 0.9263157894736842
# f1 score:	 0.20679012345679013
# ------------------------------
# evaluating label I
# ------------------------------
# accuracy:	 0.06666666666666667
# precision:	 0.25
# recall:	 0.7666666666666667
# f1 score:	 0.03125
#
#
#
# --------------------------  CROSS-VALIDATION ON TRAINING SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.825
# Average precision:	 0.275
# Average recall:	 0.953
# Average f1 score:	 0.249
# ------------
#  performance
# ------------
# Average accuracy:	 0.463
# Average precision:	 0.25
# Average recall:	 0.866
# Average f1 score:	 0.158
# ------------
#  delighter
# ------------
# Average accuracy:	 0.575
# Average precision:	 0.25
# Average recall:	 0.894
# Average f1 score:	 0.182
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.721
# Average precision:	 0.25
# Average recall:	 0.93
# Average f1 score:	 0.209
# ------------
#  overall
# ------------
# Average accuracy:	 0.645
# Average precision:	 0.64
# Average recall:	 0.646
# Average f1 score:	 0.641
#
#
#
# --------------------------  CROSS-VALIDATION ON COMBINED SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.811
# Average precision:	 0.292
# Average recall:	 0.947
# Average f1 score:	 0.262
# ------------
#  performance
# ------------
# Average accuracy:	 0.465
# Average precision:	 0.25
# Average recall:	 0.866
# Average f1 score:	 0.158
# ------------
#  delighter
# ------------
# Average accuracy:	 0.568
# Average precision:	 0.25
# Average recall:	 0.892
# Average f1 score:	 0.181
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.728
# Average precision:	 0.25
# Average recall:	 0.932
# Average f1 score:	 0.21
# ------------
#  overall
# ------------
# Average accuracy:	 0.642
# Average precision:	 0.637
# Average recall:	 0.643
# Average f1 score:	 0.637
#
#
#
#
#
#
#
#
#
#
# ======================================  ITERATION 3  ======================================
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET  -------------------------
# accuracy:	 0.6128236744759556
# precision:	 0.39830142207491787
# recall:	 0.480743871901491
# f1 score:	 0.4003975552745479
#
#
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL  -------------------------
# ------------------------------
# evaluating label B
# ------------------------------
# accuracy:	 0.6869328493647913
# precision:	 0.25
# recall:	 0.9217332123411979
# f1 score:	 0.20360408821947282
# ------------------------------
# evaluating label P
# ------------------------------
# accuracy:	 0.42025316455696204
# precision:	 0.25
# recall:	 0.8550632911392405
# f1 score:	 0.14795008912655971
# ------------------------------
# evaluating label D
# ------------------------------
# accuracy:	 0.7157894736842105
# precision:	 0.25
# recall:	 0.9289473684210526
# f1 score:	 0.2085889570552147
# ------------------------------
# evaluating label I
# ------------------------------
# accuracy:	 0.1
# precision:	 0.25
# recall:	 0.775
# f1 score:	 0.045454545454545456
#
#
#
# --------------------------  CROSS-VALIDATION ON TRAINING SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.845
# Average precision:	 0.267
# Average recall:	 0.959
# Average f1 score:	 0.244
# ------------
#  performance
# ------------
# Average accuracy:	 0.498
# Average precision:	 0.25
# Average recall:	 0.874
# Average f1 score:	 0.166
# ------------
#  delighter
# ------------
# Average accuracy:	 0.559
# Average precision:	 0.25
# Average recall:	 0.89
# Average f1 score:	 0.179
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.714
# Average precision:	 0.258
# Average recall:	 0.927
# Average f1 score:	 0.216
# ------------
#  overall
# ------------
# Average accuracy:	 0.655
# Average precision:	 0.648
# Average recall:	 0.654
# Average f1 score:	 0.649
#
#
#
# --------------------------  CROSS-VALIDATION ON COMBINED SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.819
# Average precision:	 0.258
# Average recall:	 0.954
# Average f1 score:	 0.233
# ------------
#  performance
# ------------
# Average accuracy:	 0.477
# Average precision:	 0.25
# Average recall:	 0.869
# Average f1 score:	 0.161
# ------------
#  delighter
# ------------
# Average accuracy:	 0.556
# Average precision:	 0.25
# Average recall:	 0.889
# Average f1 score:	 0.178
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.72
# Average precision:	 0.25
# Average recall:	 0.93
# Average f1 score:	 0.209
# ------------
#  overall
# ------------
# Average accuracy:	 0.642
# Average precision:	 0.636
# Average recall:	 0.643
# Average f1 score:	 0.637
#
#
#
#
#
#
#
#
#
#
# ======================================  ITERATION 4  ======================================
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET  -------------------------
# accuracy:	 0.5900123304562269
# precision:	 0.3795294051730285
# recall:	 0.4565917740663313
# f1 score:	 0.3781674618965246
#
#
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL  -------------------------
# ------------------------------
# evaluating label B
# ------------------------------
# accuracy:	 0.662431941923775
# precision:	 0.25
# recall:	 0.9156079854809438
# f1 score:	 0.19923580786026202
# ------------------------------
# evaluating label P
# ------------------------------
# accuracy:	 0.40253164556962023
# precision:	 0.25
# recall:	 0.850632911392405
# f1 score:	 0.14350180505415164
# ------------------------------
# evaluating label D
# ------------------------------
# accuracy:	 0.6947368421052632
# precision:	 0.25
# recall:	 0.9236842105263158
# f1 score:	 0.2049689440993789
# ------------------------------
# evaluating label I
# ------------------------------
# accuracy:	 0.06666666666666667
# precision:	 0.25
# recall:	 0.7666666666666667
# f1 score:	 0.03125
#
#
#
# --------------------------  CROSS-VALIDATION ON TRAINING SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.852
# Average precision:	 0.275
# Average recall:	 0.96
# Average f1 score:	 0.253
# ------------
#  performance
# ------------
# Average accuracy:	 0.504
# Average precision:	 0.25
# Average recall:	 0.876
# Average f1 score:	 0.167
# ------------
#  delighter
# ------------
# Average accuracy:	 0.587
# Average precision:	 0.258
# Average recall:	 0.893
# Average f1 score:	 0.191
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.7
# Average precision:	 0.25
# Average recall:	 0.925
# Average f1 score:	 0.206
# ------------
#  overall
# ------------
# Average accuracy:	 0.66
# Average precision:	 0.656
# Average recall:	 0.661
# Average f1 score:	 0.657
#
#
#
# --------------------------  CROSS-VALIDATION ON COMBINED SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.824
# Average precision:	 0.275
# Average recall:	 0.953
# Average f1 score:	 0.249
# ------------
#  performance
# ------------
# Average accuracy:	 0.471
# Average precision:	 0.25
# Average recall:	 0.868
# Average f1 score:	 0.16
# ------------
#  delighter
# ------------
# Average accuracy:	 0.562
# Average precision:	 0.25
# Average recall:	 0.89
# Average f1 score:	 0.179
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.737
# Average precision:	 0.258
# Average recall:	 0.933
# Average f1 score:	 0.22
# ------------
#  overall
# ------------
# Average accuracy:	 0.647
# Average precision:	 0.641
# Average recall:	 0.649
# Average f1 score:	 0.642
#
#
#
#
#
#
#
#
#
#
# ======================================  ITERATION 5  ======================================
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET  -------------------------
# accuracy:	 0.5998766954377311
# precision:	 0.39101226042225684
# recall:	 0.46863929793930487
# f1 score:	 0.38474705984225405
#
#
#
# --------------------------  TRAINING ON TRAINING SET, EVALUATION ON TEST SET --- BY LABEL  -------------------------
# ------------------------------
# evaluating label B
# ------------------------------
# accuracy:	 0.6887477313974592
# precision:	 0.25
# recall:	 0.9221869328493648
# f1 score:	 0.20392262224610422
# ------------------------------
# evaluating label P
# ------------------------------
# accuracy:	 0.3594936708860759
# precision:	 0.25
# recall:	 0.839873417721519
# f1 score:	 0.13221601489757914
# ------------------------------
# evaluating label D
# ------------------------------
# accuracy:	 0.7263157894736842
# precision:	 0.25
# recall:	 0.9315789473684211
# f1 score:	 0.21036585365853658
# ------------------------------
# evaluating label I
# ------------------------------
# accuracy:	 0.1
# precision:	 0.25
# recall:	 0.775
# f1 score:	 0.045454545454545456
#
#
#
# --------------------------  CROSS-VALIDATION ON TRAINING SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.824
# Average precision:	 0.267
# Average recall:	 0.954
# Average f1 score:	 0.241
# ------------
#  performance
# ------------
# Average accuracy:	 0.535
# Average precision:	 0.25
# Average recall:	 0.884
# Average f1 score:	 0.174
# ------------
#  delighter
# ------------
# Average accuracy:	 0.559
# Average precision:	 0.25
# Average recall:	 0.89
# Average f1 score:	 0.178
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.735
# Average precision:	 0.25
# Average recall:	 0.934
# Average f1 score:	 0.212
# ------------
#  overall
# ------------
# Average accuracy:	 0.663
# Average precision:	 0.661
# Average recall:	 0.663
# Average f1 score:	 0.659
#
#
#
# --------------------------  CROSS-VALIDATION ON COMBINED SET  -------------------------
# ------------
#  basic
# ------------
# Average accuracy:	 0.811
# Average precision:	 0.267
# Average recall:	 0.95
# Average f1 score:	 0.239
# ------------
#  performance
# ------------
# Average accuracy:	 0.499
# Average precision:	 0.25
# Average recall:	 0.875
# Average f1 score:	 0.166
# ------------
#  delighter
# ------------
# Average accuracy:	 0.574
# Average precision:	 0.25
# Average recall:	 0.893
# Average f1 score:	 0.182
# ------------
#  irrelevant
# ------------
# Average accuracy:	 0.728
# Average precision:	 0.25
# Average recall:	 0.932
# Average f1 score:	 0.21
# ------------
#  overall
# ------------
# Average accuracy:	 0.655
# Average precision:	 0.648
# Average recall:	 0.653
# Average f1 score:	 0.648
